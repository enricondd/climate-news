# %% [markdown]
# # Guardian - GET CONTENT

# %% [markdown]
# ## Import Packages

# %%
# load .env File in Environment
from dotenv import load_dotenv
# operating system interfaces - get Environment-variables
import os
# Connect to API
import requests
# create Pandas Data Frame
import pandas as pd
import datetime as dt

# %% [markdown]
# ## Endpoints
# tag_url = "http://content.guardianapis.com/tags"
#
# content_url = "https://content.guardianapis.com/search"
#
# sections_url = "https://content.guardianapis.com/sections"
#
# editions_url = "https://content.guardianapis.com/editions"
#
# single_item_url = "https://content.guardianapis.com/"

# %%
from_date = "2022-01-01"
content_url = "https://content.guardianapis.com/search"

# %% [markdown]
# ## Load Variables from .env File

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Create DataFrame function

# %%
def get_df(url: str, params: dict):
        all_results = []
        current_page = 1
        total_pages = 1
        while current_page <= total_pages:
                tic = dt.datetime.now()
                params["page"] = current_page
                try:
                        r = requests.get(url, params)
                        all_results = all_results + r.json()["response"]["results"]
                        r.raise_for_status()
                except Exception as err:
                        SystemExit(err)
                if current_page == 1:
                        total_pages = r.json()['response']['pages']
                        print("---- API STATUS ---- ")
                        print("URL: ", r.url)
                        print("status",  r.json()["response"]["status"])
                        print("total",  r.json()["response"]["total"])
                        print("startIndex",  r.json()["response"]["startIndex"])
                        print("pageSize",  r.json()["response"]["pageSize"])
                        print("pages",  r.json()["response"]["pages"])
                        print("orderBy",  r.json()["response"]["orderBy"])
                        print("---- RUNTIME STATUS ---- ")

                time_taken = str(dt.datetime.now() - tic)
                print(f"Fetched Page ({current_page}/{total_pages}) in {time_taken}s")
                        
                current_page += 1

        return pd.DataFrame(all_results)

# %% [markdown]
# ### Set Params

# %%
all_content_params = {
    "page-size": "50",
    "show-fields": ["all"],
    "show-tags": ["all"],
    "show-section": "true",
    "q":"'carbon neutrality' OR 'climate change' OR 'climate crisis' OR 'climate finance' OR 'climate justice' OR 'COP26'  OR 'ecology' OR 'extinction' OR 'global warming' OR 'green economy' OR 'greenhouse gas emissions' OR 'renewable energy' OR 'sustainability'",
    "show-blocks": ["all"],
    "show-references": ["all"],
    "show-rights": ["all"],
    "from-date": "2022-01-01",
    "to-date": "2022-05-31",
    "api-key": os.getenv("GUARDIAN_API_KEY_ENRICO1"),
}

# %% [markdown]
# ### API Request + create DF

# %%
articles_df = get_df(content_url, all_content_params)
articles_df.info()
# Out:
# ---- API STATUS ----
# URL:  https://content.guardianapis.com/search?page-size=50&show-fields=all&show-tags=all&show-section=true&q=%27carbon+neutrality%27+OR+%27climate+change%27+OR+%27climate+crisis%27+OR+%27climate+finance%27+OR+%27climate+justice%27+OR+%27COP26%27++OR+%27ecology%27+OR+%27extinction%27+OR+%27global+warming%27+OR+%27green+economy%27+OR+%27greenhouse+gas+emissions%27+OR+%27renewable+energy%27+OR+%27sustainability%27&show-blocks=all&show-references=all&show-rights=all&from-date=2022-01-01&to-date=2022-05-31&api-key=301fbb72-1708-4103-ae7a-cadd7227d7f7&page=1
# status ok
# total 5404
# startIndex 1
# pageSize 50
# pages 109
# orderBy relevance
# ---- RUNTIME STATUS ----
# Fetched Page (1/109) in 0:00:00.850425s
# Fetched Page (2/109) in 0:00:00.613845s
# Fetched Page (3/109) in 0:00:00.851927s
# Fetched Page (4/109) in 0:00:00.659375s
# Fetched Page (5/109) in 0:00:00.617402s
# Fetched Page (6/109) in 0:00:00.663936s
# Fetched Page (7/109) in 0:00:00.651046s
# Fetched Page (8/109) in 0:00:00.607558s
# Fetched Page (9/109) in 0:00:00.632009s
# Fetched Page (10/109) in 0:00:00.672787s
# Fetched Page (11/109) in 0:00:00.869270s
# Fetched Page (12/109) in 0:00:00.744006s
# Fetched Page (13/109) in 0:00:00.985385s
# Fetched Page (14/109) in 0:00:00.604771s
# Fetched Page (15/109) in 0:00:00.861156s
# Fetched Page (16/109) in 0:00:00.755494s
# Fetched Page (17/109) in 0:00:00.893483s
# Fetched Page (18/109) in 0:00:00.822176s
# Fetched Page (19/109) in 0:00:00.788871s
# Fetched Page (20/109) in 0:00:01.180514s
# Fetched Page (21/109) in 0:00:01.004679s
# Fetched Page (22/109) in 0:00:00.898608s
# Fetched Page (23/109) in 0:00:01.241482s
# Fetched Page (24/109) in 0:00:01.337230s
# Fetched Page (25/109) in 0:00:01.023732s
# Fetched Page (26/109) in 0:00:01.432131s
# Fetched Page (27/109) in 0:00:01.623004s
# Fetched Page (28/109) in 0:00:01.125703s
# Fetched Page (29/109) in 0:00:01.223408s
# Fetched Page (30/109) in 0:00:00.773571s
# Fetched Page (31/109) in 0:00:01.264948s
# Fetched Page (32/109) in 0:00:00.797630s
# Fetched Page (33/109) in 0:00:01.104647s
# Fetched Page (34/109) in 0:00:00.831404s
# Fetched Page (35/109) in 0:00:01.581531s
# Fetched Page (36/109) in 0:00:00.901906s
# Fetched Page (37/109) in 0:00:00.801175s
# Fetched Page (38/109) in 0:00:04.583563s
# Fetched Page (39/109) in 0:00:00.873846s
# Fetched Page (40/109) in 0:00:00.824757s
# Fetched Page (41/109) in 0:00:00.997306s
# Fetched Page (42/109) in 0:00:00.841156s
# Fetched Page (43/109) in 0:00:00.936990s
# Fetched Page (44/109) in 0:00:00.955270s
# Fetched Page (45/109) in 0:00:00.644379s
# Fetched Page (46/109) in 0:00:00.664671s
# Fetched Page (47/109) in 0:00:00.794837s
# Fetched Page (48/109) in 0:00:00.965966s
# Fetched Page (49/109) in 0:00:00.814303s
# Fetched Page (50/109) in 0:00:00.961088s
# Fetched Page (51/109) in 0:00:00.625763s
# Fetched Page (52/109) in 0:00:00.792912s
# Fetched Page (53/109) in 0:00:01.229847s
# Fetched Page (54/109) in 0:00:01.053889s
# Fetched Page (55/109) in 0:00:01.167600s
# Fetched Page (56/109) in 0:00:01.262562s
# Fetched Page (57/109) in 0:00:00.633115s
# Fetched Page (58/109) in 0:00:01.062219s
# Fetched Page (59/109) in 0:00:01.287540s
# Fetched Page (60/109) in 0:00:00.671703s
# Fetched Page (61/109) in 0:00:00.870113s
# Fetched Page (62/109) in 0:00:00.626612s
# Fetched Page (63/109) in 0:00:00.873467s
# Fetched Page (64/109) in 0:00:01.046969s
# Fetched Page (65/109) in 0:00:00.647459s
# Fetched Page (66/109) in 0:00:00.771012s
# Fetched Page (67/109) in 0:00:00.620000s
# Fetched Page (68/109) in 0:00:00.938529s
# Fetched Page (69/109) in 0:00:00.752214s
# Fetched Page (70/109) in 0:00:00.683107s
# Fetched Page (71/109) in 0:00:00.630627s
# Fetched Page (72/109) in 0:00:01.150340s
# Fetched Page (73/109) in 0:00:00.640259s
# Fetched Page (74/109) in 0:00:01.097695s
# Fetched Page (75/109) in 0:00:01.078306s
# Fetched Page (76/109) in 0:00:00.724273s
# Fetched Page (77/109) in 0:00:00.866992s
# Fetched Page (78/109) in 0:00:00.834497s
# Fetched Page (79/109) in 0:00:00.626508s
# Fetched Page (80/109) in 0:00:00.566539s
# Fetched Page (81/109) in 0:00:00.849745s
# Fetched Page (82/109) in 0:00:00.773691s
# Fetched Page (83/109) in 0:00:00.782710s
# Fetched Page (84/109) in 0:00:01.041308s
# Fetched Page (85/109) in 0:00:00.741381s
# Fetched Page (86/109) in 0:00:00.743230s
# Fetched Page (87/109) in 0:00:00.766210s
# Fetched Page (88/109) in 0:00:01.007096s
# Fetched Page (89/109) in 0:00:00.679968s
# Fetched Page (90/109) in 0:00:00.581911s
# Fetched Page (91/109) in 0:00:00.810337s
# Fetched Page (92/109) in 0:00:00.610373s
# Fetched Page (93/109) in 0:00:00.630903s
# Fetched Page (94/109) in 0:00:00.699364s
# Fetched Page (95/109) in 0:00:00.887167s
# Fetched Page (96/109) in 0:00:00.865242s
# Fetched Page (97/109) in 0:00:00.977955s
# Fetched Page (98/109) in 0:00:00.736309s
# Fetched Page (99/109) in 0:00:00.892197s
# Fetched Page (100/109) in 0:00:00.709384s
# Fetched Page (101/109) in 0:00:01.076258s
# Fetched Page (102/109) in 0:00:00.939324s
# Fetched Page (103/109) in 0:00:00.636363s
# Fetched Page (104/109) in 0:00:00.768495s
# Fetched Page (105/109) in 0:00:00.777211s
# Fetched Page (106/109) in 0:00:01.029636s
# Fetched Page (107/109) in 0:00:01.685301s
# Fetched Page (108/109) in 0:00:03.862936s
# Fetched Page (109/109) in 0:00:00.527054s
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5404 entries, 0 to 5403
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  5404 non-null   object
#  1   type                5404 non-null   object
#  2   sectionId           5404 non-null   object
#  3   sectionName         5404 non-null   object
#  4   webPublicationDate  5404 non-null   object
#  5   webTitle            5404 non-null   object
#  6   webUrl              5404 non-null   object
#  7   apiUrl              5404 non-null   object
#  8   fields              5404 non-null   object
#  9   tags                5404 non-null   object
#  10  references          5404 non-null   object
#  11  blocks              5404 non-null   object
#  12  rights              5404 non-null   object
#  13  section             5401 non-null   object
#  14  isHosted            5404 non-null   bool
#  15  pillarId            5345 non-null   object
#  16  pillarName          5345 non-null   object
# dtypes: bool(1), object(16)
# memory usage: 680.9+ KB

# %% [markdown]
# ### First cleaning to reduce size

# %%
articles_df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                                                      id      type  \
# 0     environment/2022/may/10/john-kerry-warns-long-...   article
# 1     environment/2022/may/15/breaking-climate-vows-...   article
# 2     environment/2022/mar/21/ukraine-war-threatens-...   article
# 3     environment/2022/apr/04/final-warning-what-doe...   article
# 4     environment/2022/may/12/oil-gas-mega-projects-...   article
# ...                                                 ...       ...
# 5399  politics/live/2022/jan/06/uk-covid-live-nhs-ba...  liveblog
# 5400  australia-news/live/2022/feb/24/australia-news...  liveblog
# 5401  australia-news/live/2022/mar/20/australia-live...  liveblog
# 5402  australia-news/live/2022/mar/06/australia-news...  liveblog
# 5403  politics/live/2022/feb/10/politics-live-boris-...  liveblog
#
#            sectionId     sectionName    webPublicationDate  \
# 0        environment     Environment  2022-05-10T18:08:53Z
# 1        environment     Environment  2022-05-15T21:58:40Z
# 2        environment     Environment  2022-03-21T09:30:21Z
# 3        environment     Environment  2022-04-04T15:21:07Z
# 4        environment     Environment  2022-05-12T13:33:55Z
# ...              ...             ...                   ...
# 5399        politics        Politics  2022-01-06T17:06:26Z
# 5400  australia-news  Australia news  2022-02-24T08:13:22Z
# 5401  australia-news  Australia news  2022-03-20T06:31:32Z
# 5402  australia-news  Australia news  2022-03-06T06:45:01Z
# 5403        politics        Politics  2022-02-10T17:55:10Z
#
#                                                webTitle  \
# 0     John Kerry warns a long Ukraine war would thre...
# 1     Breaking climate vows would be ‘monstrous self...
# 2     Ukraine war threatens global heating goals, wa...
# 3     Final warning: what does the IPCC’s third repo...
# 4     Climate chaos certain if oil and gas mega-proj...
# ...                                                 ...
# 5399  Labour claims new evidence shows Boris Johnson...
# 5400  Morrison condemns Moscow’s ‘brutal’ attack on ...
# 5401  Payne calls Russia’s actions in Ukraine ‘war c...
# 5402  More warnings in place for NSW as severe storm...
# 5403  Boris Johnson says John Major’s claim that he ...
#
#                                                  webUrl  \
# 0     https://www.theguardian.com/environment/2022/m...
# 1     https://www.theguardian.com/environment/2022/m...
# 2     https://www.theguardian.com/environment/2022/m...
# 3     https://www.theguardian.com/environment/2022/a...
# 4     https://www.theguardian.com/environment/2022/m...
# ...                                                 ...
# 5399  https://www.theguardian.com/politics/live/2022...
# 5400  https://www.theguardian.com/australia-news/liv...
# 5401  https://www.theguardian.com/australia-news/liv...
# 5402  https://www.theguardian.com/australia-news/liv...
# 5403  https://www.theguardian.com/politics/live/2022...
#
#                                                  apiUrl  \
# 0     https://content.guardianapis.com/environment/2...
# 1     https://content.guardianapis.com/environment/2...
# 2     https://content.guardianapis.com/environment/2...
# 3     https://content.guardianapis.com/environment/2...
# 4     https://content.guardianapis.com/environment/2...
# ...                                                 ...
# 5399  https://content.guardianapis.com/politics/live...
# 5400  https://content.guardianapis.com/australia-new...
# 5401  https://content.guardianapis.com/australia-new...
# 5402  https://content.guardianapis.com/australia-new...
# 5403  https://content.guardianapis.com/politics/live...
#
#                                                  fields  \
# 0     {'headline': 'John Kerry warns a long Ukraine ...
# 1     {'headline': 'Breaking climate vows would be ‘...
# 2     {'headline': 'Ukraine war threatens global hea...
# 3     {'headline': 'Final warning: what does the IPC...
# 4     {'headline': 'Climate chaos certain if oil and...
# ...                                                 ...
# 5399  {'headline': 'Labour claims new evidence shows...
# 5400  {'headline': 'Morrison condemns Moscow’s ‘brut...
# 5401  {'headline': 'Payne calls Russia’s actions in ...
# 5402  {'headline': 'More warnings in place for NSW a...
# 5403  {'headline': 'Boris Johnson says John Major’s ...
#
#                                                    tags  \
# 0     [{'id': 'environment/climate-crisis', 'type': ...
# 1     [{'id': 'environment/cop26-glasgow-climate-cha...
# 2     [{'id': 'environment/climate-crisis', 'type': ...
# 3     [{'id': 'environment/climate-crisis', 'type': ...
# 4     [{'id': 'environment/series/carbon-bombs-2022'...
# ...                                                 ...
# 5399  [{'id': 'politics/series/politics-live-with-an...
# 5400  [{'id': 'australia-news/series/australian-news...
# 5401  [{'id': 'australia-news/series/australian-news...
# 5402  [{'id': 'australia-news/series/australian-news...
# 5403  [{'id': 'politics/series/politics-live-with-an...
#
#                                              references  \
# 0     [{'id': 'rich-link/https://www.theguardian.com...
# 1     [{'id': 'rich-link/https://www.theguardian.com...
# 2     [{'id': 'rich-link/https://www.theguardian.com...
# 3                                                    []
# 4     [{'id': 'rich-link/https://www.theguardian.com...
# ...                                                 ...
# 5399  [{'id': 'rich-link/https://www.theguardian.com...
# 5400  [{'id': 'rich-link/https://www.theguardian.com...
# 5401  [{'id': 'rich-link/https://www.theguardian.com...
# 5402                                                 []
# 5403  [{'id': 'rich-link/https://www.theguardian.com...
#
#                                                  blocks  \
# 0     {'main': {'id': '627aa7d28f083b8563797bde', 'b...
# 1     {'main': {'id': '628175378f083b856379b298', 'b...
# 2     {'main': {'id': '62383b8c8f0832c62ade29c2', 'b...
# 3     {'main': {'id': '624b0aa58f08ce9799e1fca2', 'b...
# 4     {'main': {'id': '627cf7f58f08e6ce3a77d82d', 'b...
# ...                                                 ...
# 5399  {'main': {'id': '61d6b6518f085ee13aa012d7', 'b...
# 5400  {'main': {'id': '621697268f0801fb1abbf70b', 'b...
# 5401  {'main': {'id': '623646ac8f0832c62ade1e22', 'b...
# 5402  {'main': {'id': '6223d2f18f08d4a3a989fed4', 'b...
# 5403  {'main': {'id': '6204e4bb8f08b0eb1f62c4f4', 'b...
#
#                                                  rights  \
# 0     {'syndicatable': 'true', 'subscriptionDatabase...
# 1     {'syndicatable': 'true', 'subscriptionDatabase...
# 2     {'syndicatable': 'true', 'subscriptionDatabase...
# 3     {'syndicatable': 'true', 'subscriptionDatabase...
# 4     {'syndicatable': 'true', 'subscriptionDatabase...
# ...                                                 ...
# 5399  {'syndicatable': 'true', 'subscriptionDatabase...
# 5400  {'syndicatable': 'true', 'subscriptionDatabase...
# 5401  {'syndicatable': 'true', 'subscriptionDatabase...
# 5402  {'syndicatable': 'true', 'subscriptionDatabase...
# 5403  {'syndicatable': 'true', 'subscriptionDatabase...
#
#                                                 section  isHosted  \
# 0     {'id': 'environment', 'webTitle': 'Environment...     False
# 1     {'id': 'environment', 'webTitle': 'Environment...     False
# 2     {'id': 'environment', 'webTitle': 'Environment...     False
# 3     {'id': 'environment', 'webTitle': 'Environment...     False
# 4     {'id': 'environment', 'webTitle': 'Environment...     False
# ...                                                 ...       ...
# 5399  {'id': 'politics', 'webTitle': 'Politics', 'we...     False
# 5400  {'id': 'australia-news', 'webTitle': 'Australi...     False
# 5401  {'id': 'australia-news', 'webTitle': 'Australi...     False
# 5402  {'id': 'australia-news', 'webTitle': 'Australi...     False
# 5403  {'id': 'politics', 'webTitle': 'Politics', 'we...     False
#
#          pillarId pillarName
# 0     pillar/news       News
# 1     pillar/news       News
# 2     pillar/news       News
# 3     pillar/news       News
# 4     pillar/news       News
# ...           ...        ...
# 5399  pillar/news       News
# 5400  pillar/news       News
# 5401  pillar/news       News
# 5402  pillar/news       News
# 5403  pillar/news       News
#
# [5404 rows x 17 columns]>

# %%
articles_df.drop(columns=["sectionId", "webUrl", "apiUrl","references", "blocks", "rights", "section", "isHosted", "pillarId"])
# Out:
#                                                      id      type  \
# 0     environment/2022/may/10/john-kerry-warns-long-...   article
# 1     environment/2022/may/15/breaking-climate-vows-...   article
# 2     environment/2022/mar/21/ukraine-war-threatens-...   article
# 3     environment/2022/apr/04/final-warning-what-doe...   article
# 4     environment/2022/may/12/oil-gas-mega-projects-...   article
# ...                                                 ...       ...
# 5399  politics/live/2022/jan/06/uk-covid-live-nhs-ba...  liveblog
# 5400  australia-news/live/2022/feb/24/australia-news...  liveblog
# 5401  australia-news/live/2022/mar/20/australia-live...  liveblog
# 5402  australia-news/live/2022/mar/06/australia-news...  liveblog
# 5403  politics/live/2022/feb/10/politics-live-boris-...  liveblog
#
#          sectionName    webPublicationDate  \
# 0        Environment  2022-05-10T18:08:53Z
# 1        Environment  2022-05-15T21:58:40Z
# 2        Environment  2022-03-21T09:30:21Z
# 3        Environment  2022-04-04T15:21:07Z
# 4        Environment  2022-05-12T13:33:55Z
# ...              ...                   ...
# 5399        Politics  2022-01-06T17:06:26Z
# 5400  Australia news  2022-02-24T08:13:22Z
# 5401  Australia news  2022-03-20T06:31:32Z
# 5402  Australia news  2022-03-06T06:45:01Z
# 5403        Politics  2022-02-10T17:55:10Z
#
#                                                webTitle  \
# 0     John Kerry warns a long Ukraine war would thre...
# 1     Breaking climate vows would be ‘monstrous self...
# 2     Ukraine war threatens global heating goals, wa...
# 3     Final warning: what does the IPCC’s third repo...
# 4     Climate chaos certain if oil and gas mega-proj...
# ...                                                 ...
# 5399  Labour claims new evidence shows Boris Johnson...
# 5400  Morrison condemns Moscow’s ‘brutal’ attack on ...
# 5401  Payne calls Russia’s actions in Ukraine ‘war c...
# 5402  More warnings in place for NSW as severe storm...
# 5403  Boris Johnson says John Major’s claim that he ...
#
#                                                  fields  \
# 0     {'headline': 'John Kerry warns a long Ukraine ...
# 1     {'headline': 'Breaking climate vows would be ‘...
# 2     {'headline': 'Ukraine war threatens global hea...
# 3     {'headline': 'Final warning: what does the IPC...
# 4     {'headline': 'Climate chaos certain if oil and...
# ...                                                 ...
# 5399  {'headline': 'Labour claims new evidence shows...
# 5400  {'headline': 'Morrison condemns Moscow’s ‘brut...
# 5401  {'headline': 'Payne calls Russia’s actions in ...
# 5402  {'headline': 'More warnings in place for NSW a...
# 5403  {'headline': 'Boris Johnson says John Major’s ...
#
#                                                    tags pillarName
# 0     [{'id': 'environment/climate-crisis', 'type': ...       News
# 1     [{'id': 'environment/cop26-glasgow-climate-cha...       News
# 2     [{'id': 'environment/climate-crisis', 'type': ...       News
# 3     [{'id': 'environment/climate-crisis', 'type': ...       News
# 4     [{'id': 'environment/series/carbon-bombs-2022'...       News
# ...                                                 ...        ...
# 5399  [{'id': 'politics/series/politics-live-with-an...       News
# 5400  [{'id': 'australia-news/series/australian-news...       News
# 5401  [{'id': 'australia-news/series/australian-news...       News
# 5402  [{'id': 'australia-news/series/australian-news...       News
# 5403  [{'id': 'politics/series/politics-live-with-an...       News
#
# [5404 rows x 8 columns]

# %% [markdown]
# ### Create CSV

# %%
articles_df.to_csv("../data/G_2022_climate_raw.csv", index=False)

# %%
articles_df.head()
# Out:
#                                                   id     type    sectionId  \
# 0  environment/2022/may/10/john-kerry-warns-long-...  article  environment
# 1  environment/2022/may/15/breaking-climate-vows-...  article  environment
# 2  environment/2022/mar/21/ukraine-war-threatens-...  article  environment
# 3  environment/2022/apr/04/final-warning-what-doe...  article  environment
# 4  environment/2022/may/12/oil-gas-mega-projects-...  article  environment
#
#    sectionName    webPublicationDate  \
# 0  Environment  2022-05-10T18:08:53Z
# 1  Environment  2022-05-15T21:58:40Z
# 2  Environment  2022-03-21T09:30:21Z
# 3  Environment  2022-04-04T15:21:07Z
# 4  Environment  2022-05-12T13:33:55Z
#
#                                             webTitle  \
# 0  John Kerry warns a long Ukraine war would thre...
# 1  Breaking climate vows would be ‘monstrous self...
# 2  Ukraine war threatens global heating goals, wa...
# 3  Final warning: what does the IPCC’s third repo...
# 4  Climate chaos certain if oil and gas mega-proj...
#
#                                               webUrl  \
# 0  https://www.theguardian.com/environment/2022/m...
# 1  https://www.theguardian.com/environment/2022/m...
# 2  https://www.theguardian.com/environment/2022/m...
# 3  https://www.theguardian.com/environment/2022/a...
# 4  https://www.theguardian.com/environment/2022/m...
#
#                                               apiUrl  \
# 0  https://content.guardianapis.com/environment/2...
# 1  https://content.guardianapis.com/environment/2...
# 2  https://content.guardianapis.com/environment/2...
# 3  https://content.guardianapis.com/environment/2...
# 4  https://content.guardianapis.com/environment/2...
#
#                                               fields  \
# 0  {'headline': 'John Kerry warns a long Ukraine ...
# 1  {'headline': 'Breaking climate vows would be ‘...
# 2  {'headline': 'Ukraine war threatens global hea...
# 3  {'headline': 'Final warning: what does the IPC...
# 4  {'headline': 'Climate chaos certain if oil and...
#
#                                                 tags  \
# 0  [{'id': 'environment/climate-crisis', 'type': ...
# 1  [{'id': 'environment/cop26-glasgow-climate-cha...
# 2  [{'id': 'environment/climate-crisis', 'type': ...
# 3  [{'id': 'environment/climate-crisis', 'type': ...
# 4  [{'id': 'environment/series/carbon-bombs-2022'...
#
#                                           references  \
# 0  [{'id': 'rich-link/https://www.theguardian.com...
# 1  [{'id': 'rich-link/https://www.theguardian.com...
# 2  [{'id': 'rich-link/https://www.theguardian.com...
# 3                                                 []
# 4  [{'id': 'rich-link/https://www.theguardian.com...
#
#                                               blocks  \
# 0  {'main': {'id': '627aa7d28f083b8563797bde', 'b...
# 1  {'main': {'id': '628175378f083b856379b298', 'b...
# 2  {'main': {'id': '62383b8c8f0832c62ade29c2', 'b...
# 3  {'main': {'id': '624b0aa58f08ce9799e1fca2', 'b...
# 4  {'main': {'id': '627cf7f58f08e6ce3a77d82d', 'b...
#
#                                               rights  \
# 0  {'syndicatable': 'true', 'subscriptionDatabase...
# 1  {'syndicatable': 'true', 'subscriptionDatabase...
# 2  {'syndicatable': 'true', 'subscriptionDatabase...
# 3  {'syndicatable': 'true', 'subscriptionDatabase...
# 4  {'syndicatable': 'true', 'subscriptionDatabase...
#
#                                              section  isHosted     pillarId  \
# 0  {'id': 'environment', 'webTitle': 'Environment...     False  pillar/news
# 1  {'id': 'environment', 'webTitle': 'Environment...     False  pillar/news
# 2  {'id': 'environment', 'webTitle': 'Environment...     False  pillar/news
# 3  {'id': 'environment', 'webTitle': 'Environment...     False  pillar/news
# 4  {'id': 'environment', 'webTitle': 'Environment...     False  pillar/news
#
#   pillarName
# 0       News
# 1       News
# 2       News
# 3       News
# 4       News
